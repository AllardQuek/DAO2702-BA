# %% [markdown]
# ## Question 1
#
# 1. The variable `data` is defined to be the data frame below.
#
# | |**Employee_Name**|**PayRate**|**Position**|**DOB**|**Sex**|**Married**|
# |----:|---------------:|-----------:|----------:|------:|-------:|-------:|
# |**0**| Brown, Mia | 28.5 | Accountant I | 11/24/87 | F | True |
# |**1**| LaRotonda, William | 23.0 | Accountant I | 04/26/84 | M | False |
# |**2**| Steans, Tyrone | 29.0 | Account I | 09/01/86 | M | False |
# |**...**| ... | ... | ... | ... | ... | ... |
# |**307**| Semizoglou, Jeremiah | 53.8 | Sr. Network Engineer | 02/09/83 | M | True |
# |**308**| South, Joe | 53.0 | Sr. Network Engineer | 09/09/65 | M | False |
# |**309**| Warfield, Sarah | 55.2 | Sr. Network Engineer | 05/02/78 | F | False |
#
# The column **DOB** gives the date of birth expressed as MM/DD/YY for each individual. Which of the following code segments is correct in creating a new column `Age` that is the age (2022 - birth year) of the individual? (Ans: C)
#
#     A.
# ---
# ```python
# data['Age'] = 122 – data['DOB'].astype(str)[-2:].astype(int)
# ```
# ---
#
#     B.
# ---
# ```python
# data['Age'] = 122 – data['DOB'].str.astype(str)[-2:].astype(int)
# ```
# ---
#
#     C.
# ---
# ```python
# data['Age'] = 122 – data['DOB'].str[-2:].astype(int)
# ```
# ---
#
#     D.
# ---
# ```python
# data['Age'] = 122 – str(data['DOB'])[-2:].astype(int)
# ```
# ---

# %% [markdown]
# ## Question 2
#
# Considering the following dataset on Singapore private house properties.

# %%
import pandas as pd

prop = pd.read_csv('properties2.csv')
prop
# Out:
#                        project                   street         type  \
# 0                PARC CLEMATIS            JALAN LEMPENG    Apartment
# 1               ONE PEARL BANK               PEARL BANK    Apartment
# 2               ONE PEARL BANK               PEARL BANK    Apartment
# 3               ONE PEARL BANK               PEARL BANK    Apartment
# 4                    THE CREST  PRINCE CHARLES CRESCENT  Condominium
# ...                        ...                      ...          ...
# 104896              FLORAVILLE              CACTUS ROAD    Apartment
# 104897         EUPHONY GARDENS          JALAN MATA AYER  Condominium
# 104898         SYMPHONY SUITES             YISHUN CLOSE  Condominium
# 104899         SYMPHONY SUITES             YISHUN CLOSE  Condominium
# 104900  SELETAR PARK RESIDENCE             SELETAR ROAD  Condominium
#
#         district segment    tenure  commence      sale    price  area  \
# 0              5     OCR  99 years    2019.0  New Sale  2567000  1496
# 1              3     RCR  99 years    2019.0  New Sale  2986000  1281
# 2              3     RCR  99 years    2019.0  New Sale  1835000   700
# 3              3     RCR  99 years    2019.0  New Sale  1924000   840
# 4              3     RCR  99 years    2012.0    Resale  1620000   883
# ...          ...     ...       ...       ...       ...      ...   ...
# 104896        28     OCR  freehold       NaN  New Sale   910000   818
# 104897        27     OCR  99 years    1998.0    Resale   739998  1044
# 104898        27     OCR  99 years    2014.0  New Sale   875000   797
# 104899        27     OCR  99 years    2014.0  New Sale   759000   689
# 104900        28     OCR  99 years    2011.0    Resale  1060000   872
#
#            level    date
# 0       11 to 15  Dec-21
# 1       16 to 20  Dec-21
# 2       21 to 25  Dec-21
# 3       06 to 10  Dec-21
# 4       11 to 15  Dec-21
# ...          ...     ...
# 104896  01 to 05  Jan-17
# 104897  01 to 05  Jan-17
# 104898  11 to 15  Jan-17
# 104899  11 to 15  Jan-17
# 104900  01 to 05  Jan-17
#
# [104901 rows x 12 columns]

# %% [markdown]
# Details of the variables are given below:
# - `project`: The name of the property project.
# - `street`: The street name of the property.
# - `type`: The type of the property: apartment or condominium.
# - `district`: Location of the property, given as the district code of Singapore, details can be found [here](https://www.mingproperty.sg/singapore-district-code/).
# - `segment`: Location of the property, given as the region segment of Singapore: Core Central Region (CCR), Rest of Central Region (RCR), or the Outside Central Region (OCR).
# - `tenure`: The tenure type of the property: 99 years or freehold.
# - `commence`: The commencing year of the property.
# - `sale`: The sales type of the property: new sale or resale.
# - `price`: The total price (in Singapore Dollars) of the property.
# - `area`: The area of the property in square feet.
# - `level`: The levels of the condos.
# - `date`: The date of the transaction.
#
# 1. What is the percentage of records that have the commencing year to be missing?

# %%
prop['commence'].isnull().mean()
# Out:
# 0.2824281942021525

# %% [markdown]
# 2. Create a new column called `price_psf` that is the per square foot price of these properties, i.e. the total price divided by the area.

# %%
prop['price_psf'] = prop['price'] / prop['area']
prop
# Out:
#                        project                   street         type  \
# 0                PARC CLEMATIS            JALAN LEMPENG    Apartment
# 1               ONE PEARL BANK               PEARL BANK    Apartment
# 2               ONE PEARL BANK               PEARL BANK    Apartment
# 3               ONE PEARL BANK               PEARL BANK    Apartment
# 4                    THE CREST  PRINCE CHARLES CRESCENT  Condominium
# ...                        ...                      ...          ...
# 104896              FLORAVILLE              CACTUS ROAD    Apartment
# 104897         EUPHONY GARDENS          JALAN MATA AYER  Condominium
# 104898         SYMPHONY SUITES             YISHUN CLOSE  Condominium
# 104899         SYMPHONY SUITES             YISHUN CLOSE  Condominium
# 104900  SELETAR PARK RESIDENCE             SELETAR ROAD  Condominium
#
#         district segment    tenure  commence      sale    price  area  \
# 0              5     OCR  99 years    2019.0  New Sale  2567000  1496
# 1              3     RCR  99 years    2019.0  New Sale  2986000  1281
# 2              3     RCR  99 years    2019.0  New Sale  1835000   700
# 3              3     RCR  99 years    2019.0  New Sale  1924000   840
# 4              3     RCR  99 years    2012.0    Resale  1620000   883
# ...          ...     ...       ...       ...       ...      ...   ...
# 104896        28     OCR  freehold       NaN  New Sale   910000   818
# 104897        27     OCR  99 years    1998.0    Resale   739998  1044
# 104898        27     OCR  99 years    2014.0  New Sale   875000   797
# 104899        27     OCR  99 years    2014.0  New Sale   759000   689
# 104900        28     OCR  99 years    2011.0    Resale  1060000   872
#
#            level    date    price_psf
# 0       11 to 15  Dec-21  1715.909091
# 1       16 to 20  Dec-21  2330.991413
# 2       21 to 25  Dec-21  2621.428571
# 3       06 to 10  Dec-21  2290.476190
# 4       11 to 15  Dec-21  1834.654587
# ...          ...     ...          ...
# 104896  01 to 05  Jan-17  1112.469438
# 104897  01 to 05  Jan-17   708.810345
# 104898  11 to 15  Jan-17  1097.867001
# 104899  11 to 15  Jan-17  1101.596517
# 104900  01 to 05  Jan-17  1215.596330
#
# [104901 rows x 13 columns]

# %% [markdown]
# 3. How many records in the dataset are condos/apartments located in district 5 and their levels are higher than 20?
#
# **Solution**:

# %%
level_from = prop['level'].str[:2].astype(int)
level_from
# Out:
# 0         11
# 1         16
# 2         21
# 3          6
# 4         11
#           ..
# 104896     1
# 104897     1
# 104898    11
# 104899    11
# 104900     1
# Name: level, Length: 104901, dtype: int64

# %%
cond1 = prop['district'] == 5
cond2 = level_from > 20

(cond1 & cond2).sum()
# Out:
# 2288

# %% [markdown]
# 4. What is the average per square foot price of all condos/apartments located in district 5 and their levels are higher than 20?
# **Solution**:

# %%
subset = prop.loc[cond1&cond2].reset_index(drop=True)
subset
# Out:
#                  project             street         type  district segment  \
# 0         NORMANTON PARK     NORMANTON PARK    Apartment         5     RCR
# 1         NORMANTON PARK     NORMANTON PARK    Apartment         5     RCR
# 2         NORMANTON PARK     NORMANTON PARK    Apartment         5     RCR
# 3     THE CLEMENT CANOPY  CLEMENTI AVENUE 1    Apartment         5     OCR
# 4     THE CLEMENT CANOPY  CLEMENTI AVENUE 1    Apartment         5     OCR
# ...                  ...                ...          ...       ...     ...
# 2283        PARC RIVIERA    WEST COAST VALE  Condominium         5     OCR
# 2284         THE TRILINQ      JALAN LEMPENG  Condominium         5     OCR
# 2285         THE TRILINQ      JALAN LEMPENG  Condominium         5     OCR
# 2286         THE TRILINQ      JALAN LEMPENG  Condominium         5     OCR
# 2287         THE TRILINQ      JALAN LEMPENG  Condominium         5     OCR
#
#         tenure  commence      sale    price  area     level    date  \
# 0     99 years    2019.0  New Sale  2088000  1098  21 to 25  Dec-21
# 1     99 years    2019.0  New Sale  1762000   969  21 to 25  Dec-21
# 2     99 years    2019.0  New Sale  1033230   527  21 to 25  Dec-21
# 3     99 years    2016.0    Resale  1050000   657  26 to 30  Dec-21
# 4     99 years    2016.0    Resale  1268800   710  31 to 35  Dec-21
# ...        ...       ...       ...      ...   ...       ...     ...
# 2283  99 years    2015.0  New Sale   594000   463  26 to 30  Jan-17
# 2284  99 years    2012.0  New Sale  1071000   710  21 to 25  Jan-17
# 2285  99 years    2012.0  New Sale  1076000   710  21 to 25  Jan-17
# 2286  99 years    2012.0  New Sale  1656000  1346  26 to 30  Jan-17
# 2287  99 years    2012.0  New Sale  1457000  1044  26 to 30  Jan-17
#
#         price_psf
# 0     1901.639344
# 1     1818.369453
# 2     1960.588235
# 3     1598.173516
# 4     1787.042254
# ...           ...
# 2283  1282.937365
# 2284  1508.450704
# 2285  1515.492958
# 2286  1230.312036
# 2287  1395.593870
#
# [2288 rows x 13 columns]

# %%
subset['price_psf'].mean()
# Out:
# 1510.5381225211797

# %% [markdown]
# 5. Consider all condos/apartments transactions that were done in 2020 or later, what is the median of the areas?
#
# **Solution**:

# %%
year = prop['date'].str[-2:].astype(int)
year >= 20
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 104896    False
# 104897    False
# 104898    False
# 104899    False
# 104900    False
# Name: date, Length: 104901, dtype: bool

# %%
prop.loc[year >= 20, 'area'].median()
# Out:
# 936.0

# %%
# Alternatively
prop[prop['date'].str[-2:].astype(int) >= 20]['area'].median()
# Out:
# 936.0

# %% [markdown]
# 6. Consider all transactions that were done in 2020 or later, what is the percentage of condos/apartments that are located in the RCR region?
#
# **Solution**:

# %%
prop.loc[year >= 20, 'segment'].value_counts()
# Out:
# OCR    22059
# RCR    16688
# CCR     8574
# Name: segment, dtype: int64

# %%
prop.loc[year >= 20, 'segment'].value_counts(normalize=True)
# Out:
# OCR    0.466157
# RCR    0.352655
# CCR    0.181188
# Name: segment, dtype: float64

# %% [markdown]
# 7. Consider transaction records that are 1) resale condos with a 99-year tenure; 2) with a total price between 2,000,000 and 2,200,000; and 3) sold in the year of 2021, use data visualization to show how the commencing years affect the per square foot prices.
#
# **Solution**:

# %%
cond1 = (prop['type'] == 'Condominium') & (prop['sale'] == 'Resale') & (prop['tenure'] == '99 years')
cond2 = (prop['price'] >= 2000000) & (prop['price'] <= 2200000)
cond3 = prop['date'].str[-2:] == '21'

subset = prop.loc[cond1 & cond2 & cond3].reset_index(drop=True)
subset
# Out:
#                        project                   street         type  \
# 0    REFLECTIONS AT KEPPEL BAY          KEPPEL BAY VIEW  Condominium
# 1                  THE TRILINQ            JALAN LEMPENG  Condominium
# 2      CARIBBEAN AT KEPPEL BAY         KEPPEL BAY DRIVE  Condominium
# 3                    THE CREST  PRINCE CHARLES CRESCENT  Condominium
# 4                  THE TRILINQ            JALAN LEMPENG  Condominium
# ..                         ...                      ...          ...
# 219                THE MADEIRA    BUKIT BATOK STREET 31  Condominium
# 220                GARDENVISTA             DUNEARN ROAD  Condominium
# 221             SKIES MILTONIA           MILTONIA CLOSE  Condominium
# 222     SELETAR PARK RESIDENCE             SELETAR ROAD  Condominium
# 223     SELETAR PARK RESIDENCE             SELETAR ROAD  Condominium
#
#      district segment    tenure  commence    sale    price  area     level  \
# 0           4     RCR  99 years    2006.0  Resale  2060000  1152  06 to 10
# 1           5     OCR  99 years    2012.0  Resale  2100000  1518  11 to 15
# 2           4     RCR  99 years    1999.0  Resale  2100000  1335  01 to 05
# 3           3     RCR  99 years    2012.0  Resale  2200000  1216  11 to 15
# 4           5     OCR  99 years    2012.0  Resale  2190000  1518  16 to 20
# ..        ...     ...       ...       ...     ...      ...   ...       ...
# 219        23     OCR  99 years    2000.0  Resale  2060000  3046  26 to 30
# 220        21     RCR  99 years    1999.0  Resale  2050000  1346  06 to 10
# 221        27     OCR  99 years    2012.0  Resale  2200000  2842  11 to 15
# 222        28     OCR  99 years    2011.0  Resale  2040000  2239  01 to 05
# 223        28     OCR  99 years    2011.0  Resale  2080000  2314  01 to 05
#
#        date    price_psf
# 0    Dec-21  1788.194444
# 1    Dec-21  1383.399209
# 2    Dec-21  1573.033708
# 3    Dec-21  1809.210526
# 4    Nov-21  1442.687747
# ..      ...          ...
# 219  Mar-21   676.296783
# 220  Mar-21  1523.031204
# 221  Oct-21   774.102745
# 222  Oct-21   911.121036
# 223  Oct-21   898.876404
#
# [224 rows x 13 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(subset['commence'], subset['price_psf'], alpha=0.5)
plt.xlabel('Commencing year', fontsize=12)
plt.ylabel('Price (S$/sqft)', fontsize=12)
plt.show()

# %%
ocr = subset.loc[subset['segment'] == 'OCR']
rcr = subset.loc[subset['segment'] == 'RCR']
ccr = subset.loc[subset['segment'] == 'CCR']

plt.scatter(ocr['commence'], ocr['price_psf'], color='b', alpha=0.5, label='OCR')
plt.scatter(rcr['commence'], rcr['price_psf'], color='r', alpha=0.5, label='RCR')
plt.scatter(ccr['commence'], ccr['price_psf'], color='g', alpha=0.5, label='CCR')
plt.xlabel('Commencing year', fontsize=12)
plt.ylabel('Price (S$/sqft)', fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# ## Question 3
#
# In the research paper [*Chocolate Consumption, Cognitive Function, and Nobel Laureates*](https://www.nejm.org/doi/full/10.1056/nejmon1211064) published on *New England Journal of Medicine*, the author is trying to prove that chocolate consumption may improve cognitive function not only in individuals but in whole populations. The main evidence is shown by the following figure.
#
# <img src="https://github.com/XiongPengNUS/dao_resources/blob/main/choco_nobel.png?raw=true" width=600>
#
# Do you agree that the data visual above is sufficient in proving that consuming chocolate will improve the cognitive function of the whole population?
#
# **Solution**:
#
# The evidence is insufficient. The positive correlation may be caused by other confounders, such as GDP per capita, expenditures on eduction and research.
